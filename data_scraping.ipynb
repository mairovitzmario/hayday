# %%
import requests
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# Data Scraping

# %%
url = "https://hayday.fandom.com/wiki/Goods_List"  

response = requests.get(url)
response.raise_for_status() 

soup = BeautifulSoup(response.text, 'html.parser')


table = soup.find('table')


headers = [header.text.strip() for header in table.find_all('th')]
headers = headers

rows = []
for row in table.find_all('tr'):
    cells = row.find_all(['th', 'td'])
    row_data = [cell.text.strip() for cell in cells]
    rows.append(row_data)
print(rows)



with open('data/hayday_item_data.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(headers)  
    writer.writerows(rows[1:])  



print("Data saved to data/hayday_item_data.csv")
# Out:
# [['Name', 'Level', 'Max. price', 'Time', 'XP', 'Needs', 'Source', 'Per boat crate'], ['Wheat', '1', '3', '2 min', '1', 'Wheat\xa0(1)', 'Field (1st crop)', '50-101'], ['Egg', '1', '18', '20 min', '2', 'Chicken feed\xa0(1)', 'Chicken (1st animal product)', '15-24'], ['Corn', '2', '7', '5 min', '1', 'Corn\xa0(1)', 'Field (2nd crop)', '50-87'], ['Bread', '2', '21', '5 min★★★ 4 min', '3', 'Wheat\xa0(3)', 'Bakery', '14-26'], ['Chicken feed', '3', '7', '5 min★★★ 4 min', '1', 'Corn\xa0(1)\nWheat\xa0(2)', 'Feed Mill', 'N/A'], ['Soybean', '5', '10', '20 min', '2', 'Soybean\xa0(1)', 'Field (3rd crop)', '24-48'], ['Cow feed', '6', '14', '10 min★★★ 8 min', '2', 'Corn\xa0(1)\nSoybean\xa0(2)', 'Feed Mill', 'N/A'], ['Milk', '6', '32', '1 h', '3', 'Cow feed\xa0(1)', 'Cow (2nd animal product)', '8-16'], ['Cream', '6', '50', '20 min★★★ 17 min', '6', 'Milk\xa0(1)', 'Dairy', '8-12'], ['Sugarcane', '7', '14', '30 min', '3', 'Sugarcane\xa0(1)', 'Field (4th crop)', '14-31'], ['Corn bread', '7', '72', '30 min★★★ 25 min', '8', 'Corn\xa0(2)\nEgg\xa0(2)', 'Bakery', '4-8'], ['Brown sugar', '7', '32', '20 min★★★ 17 min', '4', 'Sugarcane\xa0(1)', 'Sugar Mill', '8-13'], ['Popcorn', '8', '32', '30 min★★★ 25 min', '4', 'Corn\xa0(2)', 'Popcorn Pot', '10-19'], ['Carrot', '9', '7', '10 min', '2', 'Carrot\xa0(1)', 'Field (5th crop)', '30-49'], ['Butter', '9', '82', '30 min★★★ 25 min', '10', 'Milk\xa0(2)', 'Dairy', '4-7'], ['Pancake', '9', '108', '30 min★★★ 25 min', '13', 'Brown sugar\xa0(1)\nEgg\xa0(3)', 'BBQ Grill', '3-4'], ['Pig feed', '10', '14', '20 min★★★ 17 min', '2', 'Carrot\xa0(2)\nSoybean\xa0(1)', 'Feed Mill', 'N/A'], ['Bacon', '10', '50', '4 h', '5', 'Pig feed\xa0(1)', 'Pig (3rd animal product)', '4-9'], ['Cookie', '10', '104', '1 h★★★ 51 min', '13', 'Brown sugar\xa0(1)\nEgg\xa0(2)Wheat\xa0(2)', 'Bakery', '2-5'], ['Bacon and eggs', '11', '201', '1 h★★★ 51 min', '24', 'Bacon\xa0(2)\nEgg\xa0(4)', 'BBQ Grill', '2-4'], ['Cheese', '12', '122', '1 h★★★ 51 min', '15', 'Milk\xa0(3)', 'Dairy', '3-5'], ['Indigo', '13', '25', '2 h', '5', 'Indigo\xa0(1)', 'Field (6th crop)', '8-19'], ['White sugar', '13', '50', '40 min★★★ 34 min', '6', 'Sugarcane\xa0(2)', 'Sugar Mill', '4-13'], ['Carrot pie', '14', '82', '1 h★★★ 51 min', '10', 'Carrot\xa0(3)Egg\xa0(1)Wheat\xa0(2)', 'Pie Oven', '4-7'], ['Pumpkin', '15', '32', '3 h', '6', 'Pumpkin\xa0(1)', 'Field (7th crop)', '9-16'], ['Pumpkin pie', '15', '158', '2 h★★★ 1 h 42 min', '19', 'Egg\xa0(1)\nPumpkin\xa0(3)Wheat\xa0(2)', 'Pie Oven', '3-4'], ['Apple', '15', '39', '16 h', '7', 'N/A', 'Apple tree (8th crop)', '8-14'], ['Sheep feed', '16', '14', '30 min★★★ 25 min', '3', 'Soybean\xa0(1)\nWheat\xa0(3)', 'Feed Mill', 'N/A'], ['Wool', '16', '54', '6 h', '5', 'Sheep feed\xa0(1)', 'Sheep (4th animal product)', '5-9'], ['Buttered popcorn', '16', '126', '1 h★★★ 51 min', '15', 'Butter\xa0(1)\nCorn\xa0(2)', 'Popcorn Pot', '2-5'], ['Sweater', '17', '151', '2 h★★★ 1 h 42 min', '18', 'Wool\xa0(2)', 'Loom', '3-4'], ['Cotton', '18', '28', '2 h 30 min', '6', 'Cotton\xa0(1)', 'Field (9th crop)', '10-16'], ['Bacon pie', '18', '219', '3 h★★★ 2 h 33 min', '26', 'Bacon\xa0(3)\nEgg\xa0(1)Wheat\xa0(2)', 'Pie Oven', '1-3'], ['Syrup', '18', '90', '1 h 30 min★★★ 1 h 16 min', '11', 'Sugarcane\xa0(4)', 'Sugar Mill', '2-4'], ['Cotton fabric', '18', '108', '30 min★★★ 25 min', '13', 'Cotton\xa0(3)', 'Loom', '3-5'], ['Hamburger', '18', '180', '2 h★★★ 1 h 42 min', '22', 'Bacon\xa0(2)\nBread\xa0(2)', 'BBQ Grill', '2-3'], ['Raspberry', '19', '46', '18 h', '9', 'N/A', 'Raspberry bush (10th crop)', '6-11'], ['Raspberry muffin', '19', '140', '45 min★★★ 38 min', '17', 'Egg\xa0(1)\nRaspberry\xa0(2)Wheat\xa0(2)', 'Bakery', '2-4'], ['Blue woolly hat', '19', '111', '1 h★★★ 51 min', '13', 'Indigo\xa0(1)\nWool\xa0(1)', 'Loom', '3-5'], ['Cotton shirt', '19', '241', '45 min★★★ 38 min', '29', 'Cotton fabric\xa0(2)', 'Sewing Machine', '2-3'], ['Blue sweater', '20', '208', '3 h★★★ 2 h 33 min', '25', 'Indigo\xa0(2)\nWool\xa0(2)', 'Loom', '2-3'], ['Carrot cake', '21', '165', '1 h ...
# Data saved to data/hayday_item_data.csv
